# %%
import numpy as np
ego_speed = np.load('content/ego_speed.npy')
ego_speed*=3.6

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(ego_speed)

plt.title('ego car speed(km/h)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_6251/1886922905.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
